# %%
import os;

import sys;
sys.path.insert(0,os.getcwd() + '\\..\\lib');

from Transform import GenTransform;
from Regression import LogisticRegression;



import re;
import pandas as pd;
import numpy as np;

reviewsDf= pd.read_csv(os.getcwd() +"\\datasets\\reviews_sister.csv", index_col=0, parse_dates=True, nrows= 50);

reviewsDf
# Out:
#          ProductName                                             Review  \
# ReviewId
# 1                htc                  htc is the best phone I ever used
# 2            windows                     not satisfied with this phone.
# 3             iphone  eventhough camera quality is good but the rate...
# 4            windows        battries power is too good in windows phone
# 5                htc         The hardware on this device is very nice.
# 6             iphone                        Phone won't keep a charge.
# 7             iphone   The camera takes quality pictures in good lig...
# 8                htc             Takes very poor quality pics & videos.
# 9            windows   This is a great phone but there is a major flaw
# 10               htc  Charger doesn't work and charger port on phone...
# 11           windows   Ease of use with this phone is great. But the...
# 12            iphone  I absolutely love this phone! The touchscreen ...
# 13               htc  The phone is beautiful . . . a work of art but...
# 14           windows                   The phone doesn't work properly.
# 15            iphone  The mouth pc  doesn't work unless you are on s...
# 16               htc   Overall I'm very satisfied with my purchase a...
# 17            iphone  within one month battery power has gone..iphon...
# 18               htc  Loved it for a while, but the top speaker blew...
# 19            iphone       iphone One Not bad but not  Ok for the money
# 20           windows   Came with the purple lens problem on back camera
# 21            iphone  Super fast phone. Easy to use and the speakers...
# 22           windows  The best phone I have ever owned.  Overall it'...
# 23               htc  phone itself was cosmentically in great condit...
# 24               htc   there was something wrong with my htc camera ...
# 25           windows                          Phone was absolutely bad.
# 26            iphone  I love this phone so much with user friendly a...
# 27            iphone   No echo when they spoke. All in all this phon...
# 28               htc  past several months the top speaker is well wo...
# 29           windows  I am very impressed with this phone. It has su...
# 30            iphone                          DO NOT BUY THIS PHONE!!!
# 31               htc               I won't be buying from HTC any more.
# 32            iphone  the camera takes crystal clear shots, and the ...
# 33               htc   It's the most sturdy great phone I've ever us...
# 34           windows  The front facing stereo speakers are good and ...
# 35            iphone  I m using first time i phone companys i phone ...
# 36               htc          want to exchange my phone too bad quality
# 37               htc  It's a great phone and impressive water resist...
# 38            iphone  The camera focuses and takes shots really quic...
# 39           windows   Had some issues with that early on, but the n...
# 40            iphone   the best phone i ever used in my whole life.....
# 41            iphone  I love the looks of the 5s. The performance is...
# 42           windows  My phone is draining battery too bad and getti...
# 43           windows   Sharp, bright & the text is very nice. The ha...
# 44               htc                             Good but nothing fancy
# 45               htc  Device was not working. The device crashed on ...
# 46            iphone                         Touch is so so so smooth.
# 47               htc                    Display is absolutely very bad.
# 48           windows                               Super Classy product
# 49           windows  Good product, good condition, delivery on time...
# 50           windows       this phone runs too hot and I do not like it
#
#           Sentiment
# ReviewId
# 1          positive
# 2          negative
# 3           neutral
# 4          positive
# 5          positive
# 6          negative
# 7          positive
# 8          negative
# 9           neutral
# 10         negative
# 11          neutral
# 12         positive
# 13          neutral
# 14         negative
# 15          neutral
# 16         positive
# 17        negative
# 18          neutral
# 19          neutral
# 20         negative
# 21         positive
# 22         positive
# 23          neutral
# 24         negative
# 25         negative
# 26         positive
# 27          neutral
# 28          neutral
# 29         positive
# 30         negative
# 31         negative
# 32         positive
# 33         positive
# 34         positive
# 35         positive
# 36         negative
# 37         positive
# 38         positive
# 39          neutral
# 40         positive
# 41          neutral
# 42         negative
# 43         positive
# 44          neutral
# 45         negative
# 46         positive
# 47         negative
# 48         positive
# 49          neutral
# 50         negative
